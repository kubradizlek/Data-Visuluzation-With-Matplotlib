# %% [markdown]
# <a href="https://colab.research.google.com/github/kubradizlek/Data-Visuluzation-With-Matplotlib/blob/main/Matplotlib_line_chart_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("hf://datasets/lukebarousse/data_jobs/data_jobs.csv")

# %%
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df.job_posted_date.head()
# Out:
# 0   2023-06-16 13:44:15
# 1   2023-01-14 13:18:07
# 2   2023-10-10 13:14:55
# 3   2023-07-04 13:01:41
# 4   2023-08-07 14:29:36
# Name: job_posted_date, dtype: datetime64[ns]

# %%
#Creating line chart for to show monthly job count

# %%
df['job_posted_month']=df.job_posted_date.dt.month

# %%
df.job_posted_month.value_counts()
# Out:
# job_posted_month
# 1     91822
# 8     75162
# 10    66611
# 2     64578
# 11    64450
# 3     64084
# 7     63777
# 4     62919
# 9     62359
# 6     61572
# 12    56303
# 5     52104
# Name: count, dtype: int64

# %%
df.sort_values(by='job_posted_month',ascending=True,inplace=True)

# %%
df.job_posted_month.value_counts()
# Out:
# job_posted_month
# 1     91822
# 8     75162
# 10    66611
# 2     64578
# 11    64450
# 3     64084
# 7     63777
# 4     62919
# 9     62359
# 6     61572
# 12    56303
# 5     52104
# Name: count, dtype: int64

# %%
df.head()
# Out:
#               job_title_short  \
# 203943         Data Scientist
# 709496          Data Engineer
# 709492  Senior Data Scientist
# 709486          Data Engineer
# 30379     Senior Data Analyst
#
#                                                 job_title       job_location  \
# 203943                                     Data Scientist         Denver, CO
# 709496                                      Data Engineer  West Bromwich, UK
# 709492  AIML - Senior Data Scientist - Siri and Inform...    Santa Clara, CA
# 709486                                      Data Engineer         McLean, VA
# 30379          General Assurance Data Analytics – Manager          Singapore
#
#                       job_via job_schedule_type  job_work_from_home  \
# 203943             via Adzuna         Full-time               False
# 709496  via My ArkLaMiss Jobs         Full-time               False
# 709492        via Trabajo.org         Full-time               False
# ...

# %%
monthly_count=df.job_posted_month.value_counts()

# %%
monthly_count=monthly_count.sort_index()

# %%
monthly_count
# Out:
# job_posted_month
# 1     91822
# 2     64578
# 3     64084
# 4     62919
# 5     52104
# 6     61572
# 7     63777
# 8     75162
# 9     62359
# 10    66611
# 11    64450
# 12    56303
# Name: count, dtype: int64

# %%
plt.plot(monthly_count.index,monthly_count)
