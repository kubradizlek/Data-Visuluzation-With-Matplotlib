# %% [markdown]
# <a href="https://colab.research.google.com/github/kubradizlek/Data-Visuluzation-With-Matplotlib/blob/main/Matplotlib_bar_chart_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("hf://datasets/lukebarousse/data_jobs/data_jobs.csv")

# %%
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
#Creating bar chart for to show count for each job title

# %%
job_counts= df.job_title_short.value_counts()

# %%
job_counts=job_counts.sort_values(ascending=True)

# %%
plt.barh(job_counts.index,job_counts)
# Out:
# <BarContainer object of 10 artists>
